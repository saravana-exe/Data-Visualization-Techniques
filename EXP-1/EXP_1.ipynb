# %%
print("Welcome to Music Data Analytics Lab")

print()
print()

a = 50
b = 25

print("Addition =",a+b)
print("Subtraction =",a-b)
print("Multiplication =",a*b)
print("Division =",a/b)
print()
print()

name = "Taylor Swift"
dept = "Pop"
cgpa = 9.2

print("Name:",name)
print("Department:",dept)
print("CGPA:",cgpa)

print()
print()
import numpy as np

a = np.array([100,200,300,400,500])

print(a)
print("Mean =",np.mean(a))
print("Sum =",np.sum(a))

print()
print()
import pandas as pd

data = {
'Name':['Taylor Swift','Ed Sheeran','The Weeknd'],
'Streams':[9500,8500,9000]
}

df = pd.DataFrame(data)

print(df)

print()
print()
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[100,200,150,250,300]

plt.plot(x,y)
plt.title("Sample Music Streams Line Graph")
plt.xlabel("Artist Number")
plt.ylabel("Total Streams")
plt.show()
# Out:
# Welcome to Music Data Analytics Lab
#
#
# Addition = 75
# Subtraction = 25
# Multiplication = 1250
# Division = 2.0
#
#
# Name: Taylor Swift
# Department: Pop
# CGPA: 9.2
#
#
# [100 200 300 400 500]
# Mean = 300.0
# Sum = 1500
#
#
#            Name  Streams
# 0  Taylor Swift     9500
# 1    Ed Sheeran     8500
# 2    The Weeknd     9000
